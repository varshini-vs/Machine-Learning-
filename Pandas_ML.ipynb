# %% [markdown]
# Import pandas library

# %%
import pandas as pd

# %%
rno = ['I','II','III','IV']
Sub1 = [89,90,78,98]
Sub2 = [67,90,100,100]
Sub3 = [78,89,90,89]

titles = ['RegistrationNumber', 'Mark1','Mark2','Mark3']
values = [rno,Sub1,Sub2,Sub3]
result = list(zip(titles,values))
result
# Out:
# [('RegistrationNumber', ['I', 'II', 'III', 'IV']),
#  ('Mark1', [89, 90, 78, 98]),
#  ('Mark2', [67, 90, 100, 100]),
#  ('Mark3', [78, 89, 90, 89])]

# %%
result1 = dict(result)
df1 = pd.DataFrame(result1)
print(df1)
# Out:
#   RegistrationNumber  Mark1  Mark2  Mark3
# 0                  I     89     67     78
# 1                 II     90     90     89
# 2                III     78    100     90
# 3                 IV     98    100     89

# %% [markdown]
# Importing data files from csv

# %%
df = pd.read_csv('/content/World Happiness Report 2022.csv')

# %%
df.shape
# Out:
# (146, 12)

# %%
df.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %%
df.tail()
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 141   142    Botswana*            3.471         3.667        3.275
# 142   143      Rwanda*            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 141                       0.187                         1.503
# 142                       0.536                         0.785
# 143                       0.548                         0.947
# 144                       0.216                         1.392
# 145                       1.263                         0.758
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 141                         0.815                                  0.280
# ...

# %% [markdown]
# Save df to csv

# %%
df.to_csv('happiness_dataframeToFile.csv')

# %% [markdown]
# Selection and indexing

# %%
df['Explained by: Healthy life expectancy']
# Out:
# 0      0.775
# 1      0.777
# 2      0.803
# 3      0.822
# 4      0.787
#        ...
# 141    0.280
# 142    0.462
# 143    0.270
# 144    0.631
# 145    0.289
# Name: Explained by: Healthy life expectancy, Length: 146, dtype: float64

# %%
df[['Explained by: Healthy life expectancy','Explained by: Freedom to make life choices']]
# Out:
#      Explained by: Healthy life expectancy  \
# 0                                    0.775
# 1                                    0.777
# 2                                    0.803
# 3                                    0.822
# 4                                    0.787
# ..                                     ...
# 141                                  0.280
# 142                                  0.462
# 143                                  0.270
# 144                                  0.631
# 145                                  0.289
#
#      Explained by: Freedom to make life choices
# 0                                         0.736
# 1                                         0.719
# 2                                         0.718
# 3                                         0.677
# 4                                         0.651
# ..                                          ...
# 141                                       0.571
# 142                                       0.621
# ...

# %%
df.set_index("RANK", inplace = True)
df.head()
# Out:
#           Country  Happiness score  Whisker-high  Whisker-low  \
# RANK
# 1         Finland            7.821         7.886        7.756
# 2         Denmark            7.636         7.710        7.563
# 3         Iceland            7.557         7.651        7.464
# 4     Switzerland            7.512         7.586        7.437
# 5     Netherlands            7.415         7.471        7.359
#
#       Dystopia (1.83) + residual  Explained by: GDP per capita  \
# RANK
# 1                          2.518                         1.892
# 2                          2.226                         1.953
# 3                          2.320                         1.936
# 4                          2.153                         2.026
# 5                          2.137                         1.945
#
#       Explained by: Social support  Explained by: Healthy life expectancy  \
# RANK
# 1                            1.258                                  0.775
# ...

# %%
df.reset_index(inplace=True)
df.head(3)
# Out:
#    RANK  Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1  Finland            7.821         7.886        7.756
# 1     2  Denmark            7.636         7.710        7.563
# 2     3  Iceland            7.557         7.651        7.464
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# 1                         1.243                                  0.777
# 2                         1.320                                  0.803
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.736                     0.109
# ...

# %%
type(df['Happiness score'])
# Out:
# pandas.core.series.Series

# %%
# Add a new column, eg. avg of two columns
df['Whisker-avg'] = (df['Whisker-high'] + df['Whisker-low'])/2

# %%
df.head(3)
# Out:
#    RANK  Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1  Finland            7.821         7.886        7.756
# 1     2  Denmark            7.636         7.710        7.563
# 2     3  Iceland            7.557         7.651        7.464
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# 1                         1.243                                  0.777
# 2                         1.320                                  0.803
#
#    Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                       0.736                     0.109
# ...

# %%
#Drop newly added column
df.drop('Whisker-avg',axis=1)
df.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146 entries, 0 to 145
# Data columns (total 13 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   RANK                                        146 non-null    int64
#  1   Country                                     146 non-null    object
#  2   Happiness score                             146 non-null    float64
#  3   Whisker-high                                146 non-null    float64
#  4   Whisker-low                                 146 non-null    float64
#  5   Dystopia (1.83) + residual                  146 non-null    float64
#  6   Explained by: GDP per capita                146 non-null    float64
#  7   Explained by: Social support                146 non-null    float64
#  8   Explained by: Healthy life expectancy       146 non-null    float64
# ...

# %%
print(df.describe())
# Out:
#              Rank  Happiness score  Whisker-high  Whisker-low  \
# count  146.000000       146.000000    146.000000   146.000000
# mean    73.500000         5.553575      5.673589     5.433568
# std     42.290661         1.086843      1.065621     1.109380
# min      1.000000         2.404000      2.469000     2.339000
# 25%     37.250000         4.888750      5.006250     4.754750
# 50%     73.500000         5.568500      5.680000     5.453000
# 75%    109.750000         6.305000      6.448750     6.190000
# max    146.000000         7.821000      7.886000     7.756000
#
#        Dystopia (1.83) + residual  Explained by: GDP per capita  \
# count                  146.000000                    146.000000
# mean                     1.831808                      1.410445
# std                      0.534994                      0.421663
# min                      0.187000                      0.000000
# 25%                      1.555250                      1.095500
# ...

# %%
#Type of the dataframe
print("Type:\n",type(df))
# Out:
# Type:
#  <class 'pandas.core.frame.DataFrame'>

# %%
df.drop(1,axis=0,inplace=False)
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# 5       6   Luxembourg            7.404         7.501        7.307
# ..    ...          ...              ...           ...          ...
# 141   142    Botswana*            3.471         3.667        3.275
# 142   143      Rwanda*            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                         2.518                         1.892
# ...

# %%
df.loc[4]
# Out:
# RANK                                                    5
# Country                                       Netherlands
# Happiness score                                     7.415
# Whisker-high                                        7.471
# Whisker-low                                         7.359
# Dystopia (1.83) + residual                          2.137
# Explained by: GDP per capita                        1.945
# Explained by: Social support                        1.206
# Explained by: Healthy life expectancy               0.787
# Explained by: Freedom to make life choices          0.651
# Explained by: Generosity                            0.271
# Explained by: Perceptions of corruption             0.419
# Whisker-avg                                         7.415
# Name: 4, dtype: object

# %%
df.iloc[4]
# Out:
# RANK                                                    5
# Country                                       Netherlands
# Happiness score                                     7.415
# Whisker-high                                        7.471
# Whisker-low                                         7.359
# Dystopia (1.83) + residual                          2.137
# Explained by: GDP per capita                        1.945
# Explained by: Social support                        1.206
# Explained by: Healthy life expectancy               0.787
# Explained by: Freedom to make life choices          0.651
# Explained by: Generosity                            0.271
# Explained by: Perceptions of corruption             0.419
# Whisker-avg                                         7.415
# Name: 4, dtype: object

# %%
print("Shape of dataframe:",df.shape)
df.drop_duplicates()
print(df.shape)
# Out:
# Shape of dataframe: (146, 13)
# (146, 13)

# %%
print("Columns of dataframe:\t",df.columns)
# Out:
# Columns of dataframe:	 Index(['RANK', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Whisker-avg'],
#       dtype='object')

# %%
df.rename(columns={'RANK':'Rank'},inplace=True)
print("Columns of dataframe:\t",df.columns)
# Out:
# Columns of dataframe:	 Index(['Rank', 'Country', 'Happiness score', 'Whisker-high', 'Whisker-low',
#        'Dystopia (1.83) + residual', 'Explained by: GDP per capita',
#        'Explained by: Social support', 'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Whisker-avg'],
#       dtype='object')

# %% [markdown]
# Accessing using Index - .iloc

# %%
df.iloc[0:5,4:7]
# Out:
#    Whisker-low  Dystopia (1.83) + residual  Explained by: GDP per capita
# 0        7.756                       2.518                         1.892
# 1        7.563                       2.226                         1.953
# 2        7.464                       2.320                         1.936
# 3        7.437                       2.153                         2.026
# 4        7.359                       2.137                         1.945

# %%
df3 = df['Happiness score']>5
print(df3)
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 141    False
# 142    False
# 143    False
# 144    False
# 145    False
# Name: Happiness score, Length: 146, dtype: bool

# %%
df4 = df[df3]
print(df4)
# Out:
#      Rank      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 99    100      Morocco            5.060         5.181        4.938
# 100   101   Mozambique            5.048         5.273        4.823
# 101   102     Cameroon            5.048         5.188        4.907
# 102   103      Senegal            5.046         5.171        4.921
# 103   104       Niger*            5.003         5.247        4.760
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                         2.518                         1.892
# ...

# %% [markdown]
# Using Groupby to group rows of data together and call aggregate functions

# %%
df5 = df.groupby('Happiness score').mean()
df5
# Out:
# <ipython-input-51-bd00b45cdd13>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df5 = df.groupby('Happiness score').mean()
#                   Rank  Whisker-high  Whisker-low  Dystopia (1.83) + residual  \
# Happiness score
# 2.404            146.0         2.469        2.339                       1.263
# 2.955            145.0         3.049        2.862                       0.216
# 2.995            144.0         3.110        2.880                       0.548
# 3.268            143.0         3.462        3.074                       0.536
# 3.471            142.0         3.667        3.275                       0.187
# ...                ...           ...          ...                         ...
# 7.415              5.0         7.471        7.359                       2.137
# ...

# %% [markdown]
# Visualizations

# %%
df.plot(x='Happiness score',y='Explained by: GDP per capita',kind='scatter')
# Out:
# <Axes: xlabel='Happiness score', ylabel='Explained by: GDP per capita'>

# %%
df.plot(x='Happiness score',y='Explained by: Freedom to make life choices',kind='scatter')
# Out:
# <Axes: xlabel='Happiness score', ylabel='Explained by: Freedom to make life choices'>
